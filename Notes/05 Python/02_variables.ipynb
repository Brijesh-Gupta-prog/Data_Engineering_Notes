# %% [markdown]
# # 02 - Variables and Data Types
#
# ## Introduction
#
# Variables are containers that store data. Think of them as labeled boxes where you can put different types of information.
#
# ## What You'll Learn
#
# - How to create variables
# - Different data types in Python (string, integer, float, boolean)
# - How to use and modify variables

# %% [markdown]
# ## What are Variables?
#
# A variable is a name that refers to a value. In Python:
# - You don't need to declare the type - Python figures it out automatically
# - Variable names should be descriptive
# - Use `=` to assign a value to a variable

# %% [markdown]
# ## String (Text) Variables
#
# Strings are used to store text. They are enclosed in quotes (single or double).

# %%
# String (text)
name = "Alice"
greeting = "Hello"

print("Name:", name)
print("Greeting:", greeting)
# Out:
# Name: Alice
# Greeting: Hello

# %% [markdown]
# ## Integer (Whole Number) Variables
#
# Integers are whole numbers without decimal points.

# %%
# Integer (whole number)
age = 25
count = 10

print("Age:", age)
print("Count:", count)
# Out:
# Age: 25
# Count: 10

# %% [markdown]
# ## Float (Decimal Number) Variables
#
# Floats are numbers with decimal points.

# %%
# Float (decimal number)
price = 19.99
temperature = 36.5

print("Price:", price)
print("Temperature:", temperature)
# Out:
# Price: 19.99
# Temperature: 36.5

# %% [markdown]
# ## Boolean (True/False) Variables
#
# Booleans can only have two values: `True` or `False`. They are used for conditions and logic.

# %%
# Boolean (True or False)
is_student = True
is_working = False

print("Is Student:", is_student)
print("Is Working:", is_working)
# Out:
# Is Student: True
# Is Working: False

# %% [markdown]
# ## Changing Variable Values
#
# You can change the value of a variable at any time by assigning a new value to it.

# %%
# You can change variable values
age = 25
print("Original age:", age)

age = 26  # Change the value
print("New age:", age)
# Out:
# Original age: 25
# New age: 26
