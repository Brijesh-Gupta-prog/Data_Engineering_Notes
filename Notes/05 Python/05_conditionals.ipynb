# %% [markdown]
# # 05 - Conditional Statements
#
# ## Introduction
#
# Conditional statements allow your program to make decisions based on conditions. They let your code choose different paths based on whether something is true or false.
#
# ## What You'll Learn
#
# - `if` statements
# - `if-else` statements
# - `if-elif-else` statements
# - Logical operators (`and`, `or`, `not`)

# %% [markdown]
# ## Basic if Statement
#
# The `if` statement executes code only when a condition is `True`. The code inside the `if` block is indented.

# %%
# Basic if statement
age = 18

if age >= 18:
    print("You are an adult")
# Out:
# You are an adult

# %% [markdown]
# ## if-else Statement
#
# The `else` block executes when the `if` condition is `False`. This gives you two paths: one for true, one for false.

# %%
# if-else statement
temperature = 25

if temperature > 30:
    print("It's hot outside!")
else:
    print("It's not too hot")
# Out:
# It's not too hot

# %% [markdown]
# ## if-elif-else Statement
#
# When you have multiple conditions to check, use `elif` (short for "else if"). This allows you to check multiple conditions in order.

# %%
# if-elif-else statement
score = 85

if score >= 90:
    grade = "A"
elif score >= 80:
    grade = "B"
elif score >= 70:
    grade = "C"
else:
    grade = "F"

print("Your grade is:", grade)
# Out:
# Your grade is: B

# %% [markdown]
# ## Multiple Conditions
#
# You can combine conditions using logical operators:
# - `and` - both conditions must be true
# - `or` - at least one condition must be true
# - `not` - reverses the condition

# %%
# Multiple conditions
age = 20
has_license = True

if age >= 18 and has_license:
    print("You can drive!")
elif age >= 18 and not has_license:
    print("You need a license to drive")
else:
    print("You are too young to drive")
# Out:
# You can drive!
