# %% [markdown]
# # 08 - Dictionaries
#
# ## Introduction
#
# Dictionaries store data as key-value pairs. Think of them like a phone book where you look up a name (key) to find a phone number (value).
#
# ## What You'll Learn
#
# - Creating dictionaries
# - Accessing values using keys
# - Adding and updating items
# - Dictionary methods
# - Nested dictionaries

# %% [markdown]
# ## Creating Dictionaries
#
# Dictionaries are created using curly braces `{}` with key-value pairs separated by colons.

# %%
# Create a dictionary
student = {
    "name": "Alice",
    "age": 20,
    "grade": "A"
}

print("Student info:", student)
# Out:
# Student info: {'name': 'Alice', 'age': 20, 'grade': 'A'}

# %% [markdown]
# ## Accessing Values
#
# You access dictionary values using their keys in square brackets.

# %%
# Access values using keys
print("Name:", student["name"])
print("Age:", student["age"])
# Out:
# Name: Alice
# Age: 20

# %% [markdown]
# ## Adding and Updating Items
#
# You can add new key-value pairs or update existing ones by assigning to a key.

# %%
# Add new key-value pair
student["city"] = "New York"
print("After adding city:", student)

# Change a value
student["age"] = 21
print("After updating age:", student)
# Out:
# After adding city: {'name': 'Alice', 'age': 20, 'grade': 'A', 'city': 'New York'}
# After updating age: {'name': 'Alice', 'age': 21, 'grade': 'A', 'city': 'New York'}

# %% [markdown]
# ## Dictionary Methods
#
# Dictionaries have useful methods to get keys, values, and items.

# %%
# Get all keys
print("Keys:", list(student.keys()))

# Get all values
print("Values:", list(student.values()))
# Out:
# Keys: ['name', 'age', 'grade']
# Values: ['Alice', 20, 'A']

# %% [markdown]
# ## Looping Through Dictionaries
#
# You can loop through dictionaries to access both keys and values.

# %%
# Loop through dictionary
print("Student details:")
for key, value in student.items():
    print(key + ":", value)
# Out:
# Student details:
# name: Alice
# age: 21
# grade: A
# city: New York

# %% [markdown]
# ## Nested Dictionaries
#
# Dictionaries can contain other dictionaries, allowing you to store complex data structures.

# %%
# Nested dictionary
person = {
    "name": "Bob",
    "contact": {
        "email": "bob@example.com",
        "phone": "123-456-7890"
    }
}

print("Person's email:", person["contact"]["email"])
# Out:
# Person's email: bob@example.com
