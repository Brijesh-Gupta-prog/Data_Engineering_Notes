# %% [markdown]
# # 09 - Matplotlib Exercises
#
# ## Introduction
#
# Practice makes perfect! This notebook contains exercises to reinforce what you've learned. Try to solve each exercise before looking at solutions.
#
# ## Instructions
#
# 1. Read each exercise carefully
# 2. Write your solution in the code cell
# 3. Run your code to verify it works
# 4. Compare with the solution in notebook 10

# %% [markdown]
# ## Exercise 1: Basic Line Plot
#
# Create a line plot with the following requirements:
# - X values: 0 to 10 (100 points)
# - Y values: sin(x)
# - Add proper labels and title
# - Add a grid
# - Use a professional color (e.g., 'steelblue')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Your solution here

# %% [markdown]
# ## Exercise 2: Bar Chart from DataFrame
#
# Create a DataFrame with:
# - Months: ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun']
# - Sales: [100, 120, 140, 110, 160, 180]
#
# Then create a bar chart with:
# - Custom colors
# - Value labels on top of each bar
# - Proper labels and title

# %%
import pandas as pd

# Your solution here

# %% [markdown]
# ## Exercise 3: Time Series Plot
#
# Create a time series plot for the last 30 days showing:
# - Daily records processed (random values between 1000-5000)
# - Proper date formatting on x-axis
# - Moving average (7-day window)
# - Show both original data and moving average

# %%
# Your solution here

# %% [markdown]
# ## Exercise 4: Subplots Dashboard
#
# Create a 2x2 subplot dashboard showing:
# 1. Top-left: Line plot (sin wave)
# 2. Top-right: Bar chart (any data)
# 3. Bottom-left: Scatter plot
# 4. Bottom-right: Histogram
#
# Add a main title for the entire figure.

# %%
# Your solution here

# %% [markdown]
# ## Exercise 5: Data Quality Visualization
#
# Create a visualization showing:
# - A box plot of data with outliers
# - A histogram showing the same data
# - Highlight outliers in the histogram (use different color)
#
# Use data: normal distribution (mean=100, std=15, 100 points) + outliers [50, 200, 45, 220]

# %%
# Your solution here

# %% [markdown]
# ## Exercise 6: Correlation Heatmap
#
# Create a correlation heatmap for a DataFrame with 5 columns of random data.
# - Use a color map (e.g., 'coolwarm')
# - Add correlation values as text annotations
# - Add a colorbar
# - Rotate column labels for readability

# %%
# Your solution here
