# %% [markdown]
# Database   - File -> Excel -> DB

# %% [markdown]
# Application

# %% [markdown]
# OLTP System

# %% [markdown]
# OLAP System

# %% [markdown]
# Need for Data Engineer

# %% [markdown]
# ETL
#
# ELT
#
# Data Pipelines

# %% [markdown]
# DE vs DA vs DS
